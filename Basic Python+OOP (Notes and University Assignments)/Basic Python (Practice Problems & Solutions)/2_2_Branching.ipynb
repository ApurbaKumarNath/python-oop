# %% [markdown]
# <a href="https://colab.research.google.com/github/ApurbaKumarNath/today-i-learned/blob/main/Basic%20Python%2BOOP%20(Notes%20and%20University%20Assignments)/Basic%20Python%20(Practice%20Problems%20%26%20Solutions)/2_2_Branching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input1 = int(input())
input2 = int(input())
print('Sum =', input1 + input2)
print('Product =', input1 * input2)
print('Difference =', input1 - input2)
# Out:
# 1
# 2
# Sum = 3
# Product = 2
# Difference = -1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math
radius = float(input())
print('Area is', math.pi * pow(radius, 2)) # or print(f'Area is {math.pi * radius**2}')
print('Circumference is', 2 * math.pi * radius)
# Out:
# 2
# Area is 12.566370614359172
# Circumference is 12.566370614359172

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
first = float(input())
second = float(input())
if first> second:
  print("First is greater")
elif second> first:
  print("Second is greater")
else:
  print("The numbers are equal")
# Out:
# 5
# 2
# First is greater

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input1 = float(input())
input2 = float(input())
if input1> input2:
  print(input1 - input2)
elif input2> input1:
  print(input2 - input1)
else:
  print(input1 - input2)
# Out:
# 5
# 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input1 = float(input())
if input1 % 2 == 0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# 32
# The number is even

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input1 = int(input())
if input1 % 2 == 0 or input1 % 5 == 0:
  print(input1)
else:
  print("Not a multiple of 2 OR 5")
# Out:
# 10
# 10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input1 = int(input())
if input1 % 2 == 0 and input1 % 5 == 0:
  print("Multiple of 2 and 5 both")
elif input1 % 2 == 0 or input1 % 5 == 0:
  print(input1)
else:
  print("Not a multiple we want")
# Out:
# 10
# Multiple of 2 and 5 both

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input1 = int(input())
if input1 % 2 == 0 and input1 % 5 == 0:
  print(input1)
else:
  print("Not multiple of 2 and 5 both")
# Out:
# 15
# Not multiple of 2 and 5 both

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
seconds = int(input())
hours = seconds//3600
minutes1 = (seconds % 3600)
minutes = (seconds % 3600)//60
seconds = minutes1 % 60
print('Hours:', hours, 'Minutes:', minutes, 'Seconds:', seconds)
# Out:
# 10000
# Hours: 2 Minutes: 46 Seconds: 40

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hours = int(input())

if hours<0:
  print('Hour cannot be negative')
elif hours> 168:
  print('Impossible to work more than 168 hours weekly')
elif hours <= 40:
  print(hours*200)
elif hours > 40:
  print(8000 + (hours-40)*300)
# Out:
# -1
# Hour cannot be negative

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = float(input())
if s < 100:
  print('L=', 3000 - 125*(s**2))
elif s >= 100:
  print('L=', 12000/(4+(s**2/14900)))
# Out:
# 120
# L= 2416.2162162162163

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hour = int(input())
if 0<=hour<=23:
  if 4<=hour<= 6:
    print('Breakfast')
  elif 12<=hour<=13:
    print('Lunch')
  elif 16<=hour<=17:
    print('Snacks')
  elif 19<=hour<=20:
    print('Dinner')
  else:
    print('Patience is a virtue')
else:
  print('Wrong time')
# Out:
# -6
# Wrong time

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mark = float(input())
if 0<=mark<=100:
  if 90<=mark<=100:
    print('A')
  elif 80<=mark<=89:
    print('B')
  elif 70<=mark<=79:
    print('C')
  elif 60<=mark<=69:
    print('D')
  elif 50<=mark<=59:
    print('E')
  elif mark<50:
    print('F')
else:
  print('Invalid')
# Out:
# 0
# F

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
meter = int(input())
second = int(input())
velocity= (meter/1000)/(second/3600)
print(velocity, 'km/h')

if 60<=velocity<=90:
  print('Velocity is okay. The car is ready!')
elif velocity<60:
  print('Too slow. Needs more changes.')
elif velocity> 90:
  print('Too fast. Only a few changes should suffice.')
# Out:
# 100
# 1
# 360.0 km/h
# Too fast. Only a few changes should suffice.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cgpa, credits = float(input()), int(input())
if credits>=30 and 3.8 <= cgpa <= 4.00:
  if 3.8 <= cgpa <= 3.89:
    print('The student is eligible for a waiver of 25 percent.')
  elif 3.9 <= cgpa<= 3.94:
    print('The student is eligible for a waiver of 50 percent.')
  elif 3.95 <= cgpa <= 3.99:
    print('The student is eligible for a waiver of 75 percent.')
  elif cgpa == 4.00:
    print('The student is eligible for a waiver of 100 percent.')
else:
  print('The student is not eligible for a waiver')
# Out:
# 4
# 31
# The student is eligible for a waiver of 100 percent.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i = int(input())
if i % 2 == 0 or i % 5 == 0:
  print('No')
else:
  print(i)
# Out:
# 12
# No

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input())
if x % 2 != 0 or x % 5 != 0:
  print(x)
else:
  print('No')
# Out:
# 20
# No

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
c = int(input())
p = int(input())
if c<0 or p< 0: print('Negative value given as input. May show wrong answers.')
t = c*120 + p*75
print('Previous total:', t)
if 0 <= t:
  if t < 300:
    print('New total after discount:', t)
  elif t < 500:
    print('New total after discount:', t-10)
  elif t < 750:
    print('New total after discount:', t-20)
  elif t < 1000:
    print('New total after discount:', t-50)
  elif t >= 1000:
    print('New total after discount:', t-150)
else:
  print('Value not correct.')
# Out:
# -1
# 0
# Negative value given as input. May show wrong answers.
# Previous total: -120
# Value not correct.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
t = int(input())
c = (t - 32)* 0.56
print(c, 'degree C')
if c< 20: print('Winter')
elif 20 <= c<= 25: print('Autumn')
elif 25< c < 30: print('Spring')
elif 30 <= c: print('Summer')
# Out:
# 73
# 22.96 degree C
# Autumn
