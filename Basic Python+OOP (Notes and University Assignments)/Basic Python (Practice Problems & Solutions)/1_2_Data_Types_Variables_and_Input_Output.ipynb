# %% [markdown]
# <a href="https://colab.research.google.com/github/ApurbaKumarNath/today-i-learned/blob/main/Basic%20Python%2BOOP%20(Notes%20and%20University%20Assignments)/Basic%20Python%20(Practice%20Problems%20%26%20Solutions)/1_2_Data_Types_Variables_and_Input_Output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(54+56)
# Out:
# 110

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
season = 'Summer'
year = 2023
print(season)
print(year)
# Out:
# Summer
# 2023

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = input('Name:')
print('Your name is', name)
# Out:
# Name:John
# Your name is John

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
M = int(input())
N = int(input())
print(str(M)+ '^'+ str(N)+ ':', M**N)
print(f"{M}^{N}:", M**N)
# Out:
# 2
# 3
# 2^3: 8
# 2^3: 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())
print((a//4)*4)
#print(a-(a%4)) #This does the same work.
# Out:
# 11
# 8
# 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A, B, C = int(input()), int(input()), int(input())
D = float(input())
print(int(A**C + B*A - (D/3)))
# Out:
# 2
# 6
# 8
# 1.3
# 267

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Number = int(input())
friends = Number//3
print('Each friend will receive', friends, 'chocolates')
print('The number of remaining chocolates is', (Number - 3*friends))
# Out:
# 90
# Each friend will receive 30 chocolates
# The number of remaining chocolates is 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
M = input()
N = input()
print(M+N)
# Out:
# 2
# 5
# 25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input())
y = float(input())
z = int(input())
print('The inputs:', f'{x}, {y}, {z}')
print('The result is', f'{x+y}{z}')
#print('The result is', str(x + y) + str(z)) #Same thing!
# Out:
# 3
# 11.57
# 7
# The inputs: 3, 11.57, 7
# The result is 14.577
# The result is 14.577

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())
if a%2 == 0:
  print('True')
else:
  print('False')
# Out:
# 7
# False
