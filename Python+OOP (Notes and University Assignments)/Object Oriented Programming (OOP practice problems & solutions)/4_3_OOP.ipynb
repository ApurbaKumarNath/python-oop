# %% [markdown]
# <a href="https://colab.research.google.com/github/ApurbaKumarNath/python-oop/blob/main/Python%2BOOP%20(Notes%20and%20University%20Assignments)/Object%20Oriented%20Programming%20(OOP%20practice%20problems%20%26%20solutions)/4_3_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Classwork

# %% [markdown]
# Task 1

# %%
class Student:
  def __init__(self, name, id, d = 'CSE'): #d = department
    self.name = name
    self.id = id
    self.department = d
  #def dailyEffort(self, hour):

# %% [markdown]
# Task 2

# %%
class Farmer:
  def __init__(self, id =0):
    if type(id) == int:
      print(f'Welcome to your farm. Your farm ID is {id}!')
    elif type(id) == str:
      print(f'Welcome to your farm, {id}!')
    else:
      print('Welcome to your farm!')

    self.crop = []
    self.fish = []

  def addCrops(self, *crop):
    print(len(crop), ' crop(s) added.')
    for c in crop:
      self.crop.append(c)


  def addFishes(self, *fish):
    if fish == ():
      print('No fish added.')
    else:
      for f in fish:
        self.fish.append(f)
      print(len(fish), 'fish(s) added.')

  def showGoods(self):
    if self.crop != []:
      print(f'You have {len(self.crop)} crop(s):\n{str(self.crop)[1:-1]}')
    else:
      print("You don't have any crop(s).")

    if self.fish != []:
      print(f'You have {len(self.fish)} fish(s):\n{str(self.fish)[1:-1]}')
    else:
      print("You don't have any fish(s).")






f1 = Farmer()
print("-------------------")
f1.addCrops('Rice', "Jute", "Cinnamon")
print("-------------------")
f1.addFishes()
print("-------------------")
f1.addCrops('Mustard')
print("-------------------")
f1.showGoods()
print("-------------------")
f2 = Farmer("Korim Mia")
print("-------------------")
f2.addFishes('Pangash', 'Magur')
print("-------------------")
f2.addCrops("Wheat", "Potato")
print("-------------------")
f2.addFishes("Koi", "Tuna", "Sardine")
print("-------------------")
f2.showGoods()
print("-------------------")
f3 = Farmer(2865127000)
print("-------------------")
f3.addCrops()
print("-------------------")
f3.addFishes("Katla")
print("-------------------")
f3.showGoods()
print("-------------------")
# Out:
# Welcome to your farm. Your farm ID is 0!
# -------------------
# 3  crop(s) added.
# -------------------
# No fish added.
# -------------------
# 1  crop(s) added.
# -------------------
# You have 4 crop(s):
# 'Rice', 'Jute', 'Cinnamon', 'Mustard'
# You don't have any fish(s).
# -------------------
# Welcome to your farm, Korim Mia!
# -------------------
# 2 fish(s) added.
# -------------------
# 2  crop(s) added.
# -------------------
# 3 fish(s) added.
# -------------------
# You have 2 crop(s):
# 'Wheat', 'Potato'
# You have 5 fish(s):
# 'Pangash', 'Magur', 'Koi', 'Tuna', 'Sardine'
# -------------------
# Welcome to your farm. Your farm ID is 2865127000!
# -------------------
# 0  crop(s) added.
# -------------------
# 1 fish(s) added.
# -------------------
# You don't have any crop(s).
# You have 1 fish(s):
# 'Katla'
# -------------------

# %%
class Farmer:
  def __init__(self, id =None):
    if type(id) == int:
      print(f'Welcome to your farm. Your farm ID is {id}!')
    elif type(id) == str:
      print(f'Welcome to your farm, {id}!')
    else:
      print('Welcome to your farm!')

    self.crop = ''
    self.crops = []
    self.fish = ''
    self.fishes = []

  def addCrops(self, *crop):
    if crop == ():
      print('No crop(s) added.')
    else:
      print(len(crop), ' crop(s) added.')
      for c in crop:
        self.crops.append(c)
        if self.crop == '':
          self.crop += c
        else:
          self.crop += f', {c}'


  def addFishes(self, *fish):
    if fish == ():
      print('No fish added.')
    else:
      for f in fish:
        self.fishes.append(f)
        if self.fish == '':
          self.fish += f
        else:
          self.fish += f', {f}'
        print(len(fish), 'fish(s) added.')

  def showGoods(self):
    if self.crop != '':
      print(f'You have {len(self.crops)} crop(s):\n{self.crop}')
    else:
      print("You don't have any crop(s).")

    if self.fish != '':
      print(f'You have {len(self.fishes)} fish(s):\n{self.fish}')
    else:
      print("You don't have any fish(s).")






f1 = Farmer()
print("-------------------")
f1.addCrops('Rice', "Jute", "Cinnamon")
print("-------------------")
f1.addFishes()
print("-------------------")
f1.addCrops('Mustard')
print("-------------------")
f1.showGoods()
print("-------------------")
f2 = Farmer("Korim Mia")
print("-------------------")
f2.addFishes('Pangash', 'Magur')
print("-------------------")
f2.addCrops("Wheat", "Potato")
print("-------------------")
f2.addFishes("Koi", "Tuna", "Sardine")
print("-------------------")
f2.showGoods()
print("-------------------")
f3 = Farmer(2865127000)
print("-------------------")
f3.addCrops()
print("-------------------")
f3.addFishes("Katla")
print("-------------------")
f3.showGoods()
print("-------------------")
# Out:
# Welcome to your farm!
# -------------------
# 3  crop(s) added.
# -------------------
# No fish added.
# -------------------
# 1  crop(s) added.
# -------------------
# You have 4 crop(s):
# Rice, Jute, Cinnamon, Mustard
# You don't have any fish(s).
# -------------------
# Welcome to your farm, Korim Mia!
# -------------------
# 2 fish(s) added.
# 2 fish(s) added.
# -------------------
# 2  crop(s) added.
# -------------------
# 3 fish(s) added.
# 3 fish(s) added.
# 3 fish(s) added.
# -------------------
# You have 2 crop(s):
# Wheat, Potato
# You have 5 fish(s):
# Pangash, Magur, Koi, Tuna, Sardine
# -------------------
# Welcome to your farm. Your farm ID is 2865127000!
# -------------------
# No crop(s) added.
# -------------------
# 1 fish(s) added.
# -------------------
# You don't have any crop(s).
# You have 1 fish(s):
# Katla
# -------------------

# %% [markdown]
# Task 3

# %%
class TaxiLagbe:
  def __init__(self, info, area):
    self.info = info
    self.area = area
    self.total = 0
    self.names, self.fees = '', 0
  def addPassenger(self, *p_tup):
    if self.total < 4:

      for p_fee in p_tup: #p_fee = passenger and fee
        name, fee = p_fee.split('_')
        print(f'Dear {name}! Welcome to TaxiLagbe.')
        if self.names == '':
          self.names += name
        else:
          self.names += f', {name}'
        self.fees += int(fee)
        self.total += 1
    else:
      print('Taxi Full! No more passengers can be added.')

  def printDetails(self):
    print('Trip info for Taxi number:', self.info)
    print(f'This taxi can only cover the {self.area} area.')
    print('Total passengers:', self.total)
    print(f'Passenger lists:\n{self.names}')
    print('Total collected fare:', self.fees)


taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200','Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115', 'Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can only cover the Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can only cover the Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can only cover the Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald, Parker
# Total collected fare: 330

# %% [markdown]
# Task 4

# %%
import math
class Sphere:
  def __init__(self, id, r = 1, c = 'White'): # r = radius, c = color
    self.id = id
    self.color = c
    self.volume = (4/3)*math.pi*r**3

  def printDetails(self):
    print('Sphere ID:', self.id)
    print('Color:', self.color)
    print('Volume:', self.volume)

  def merge_sphere(self,*tup_obj):
    print('Spheres are being merged')
    for obj in tup_obj:
      if self.color != obj.color:
        self.color = 'Mixed Color'
      self.volume += obj.volume

sphere1 = Sphere("Sphere 1")
print("1***************")
sphere1.printDetails()
print("2***************")
sphere2 = Sphere("Sphere 2", 3)
print("3***************")
sphere2.printDetails()
print("4***************")
sphere3 = Sphere("Sphere 3", 2)
print("5***************")
sphere3.printDetails()
print("6***************")
sphere3.merge_sphere(sphere1,sphere2)
print("7***************")
sphere3.printDetails()
print("8***************")
sphere4 = Sphere("Sphere 4", 5, "Purple")
print("9***************")
sphere4.merge_sphere(sphere3)
print("10***************")
sphere4.printDetails()
# Out:
# 1***************
# Sphere ID: Sphere 1
# Color: White
# Volume: 4.1887902047863905
# 2***************
# 3***************
# Sphere ID: Sphere 2
# Color: White
# Volume: 113.09733552923254
# 4***************
# 5***************
# Sphere ID: Sphere 3
# Color: White
# Volume: 33.510321638291124
# 6***************
# Spheres are being merged
# 7***************
# Sphere ID: Sphere 3
# Color: White
# Volume: 150.79644737231007
# 8***************
# 9***************
# Spheres are being merged
# 10***************
# Sphere ID: Sphere 4
# Color: Mixed Color
# Volume: 674.395222970609

# %% [markdown]
# #Homework

# %% [markdown]
# Task 1

# %%
class Student:
  def __init__(self, name, gpa, credit = 9, dept = 'CSE'):
    self.name = name
    self.cgpa = gpa
    self.credit = credit
    self.department = dept
  def checkScholarshipEligibility(self):
    if self.cgpa >= 3.5 and self.credit > 10:
      if self.cgpa >=3.7:
        self.status = 'Merit-based scholarship'  # scholarship status
      elif self.cgpa < 3.7:
        self.status = 'Need-based scholarship'
      print(f'{self.name} is eligible for {self.status}.')
    else:
      self.status =  'No scholarship'
      print(f'{self.name} is not eligible for scholarship.')
  def showDetails(self):
    print('Name:', self.name)
    print('Department:', self.department)
    print('CGPA:', self.cgpa)
    print('Number of Credits:', self.credit)
    print('Scholarship Status:', self.status)

print('--------------------------')
std1 = Student("Alif", 3.99, 12)
print('--------------------------')
std1.checkScholarshipEligibility()
print('--------------------------')
std1.showDetails()
print('--------------------------')
std2 = Student("Mim", 3.4)
std3 = Student("Henry", 3.5, 15,"BBA")
print('--------------------------')
std2.checkScholarshipEligibility()
print('--------------------------')
std3.checkScholarshipEligibility()
print('--------------------------')
std2.showDetails()
print('--------------------------')
std3.showDetails()
print('--------------------------')
std4 = Student("Bob", 4.0, 6, "CSE")
print('--------------------------')
std4.checkScholarshipEligibility()
print('--------------------------')
std4.showDetails()
# Out:
# --------------------------
# --------------------------
# Alif is eligible for Merit-based scholarship.
# --------------------------
# Name: Alif
# Department: CSE
# CGPA: 3.99
# Number of Credits: 12
# Scholarship Status: Merit-based scholarship
# --------------------------
# --------------------------
# Mim is not eligible for scholarship.
# --------------------------
# Henry is eligible for Need-based scholarship.
# --------------------------
# Name: Mim
# Department: CSE
# CGPA: 3.4
# Number of Credits: 9
# Scholarship Status: No scholarship
# --------------------------
# Name: Henry
# Department: BBA
# CGPA: 3.5
# Number of Credits: 15
# Scholarship Status: Need-based scholarship
# --------------------------
# --------------------------
# Bob is not eligible for scholarship.
# --------------------------
# Name: Bob
# Department: CSE
# CGPA: 4.0
# Number of Credits: 6
# Scholarship Status: No scholarship

# %% [markdown]
# Task 2

# %%
class Foodie:
  def __init__(self, name):
    self.name = name
    self.spent = 0
    self.items = []
  def show_orders(self):
    a = f'{self.name} has {len(self.items)} item(s) in the cart. \n'
    b = f'Items: {self.items} \n'
    c = f'Total spent: {self.spent}.'
    return a + b + c
  def order(self, *tup): # all orders
    for i in tup: # i = item-quantity
      item, q = i.split('-') # q = quantity
      self.items.append(item)
      q = int(q)
      p = menu[item] # p = price
      print(f'Ordered - {item}, quantity - {q}, price (per Unit) - {p}.')
      tprice = p*q
      print('Total price -', tprice)
      self.spent += tprice
  def pay_tips(self, tip = 0):
    if tip > 0:
      print(f'Gives {tip}/- tips to the waiter.')
      self.spent += tip
    else:
      print('No tips to the waiter.')


menu = {'Chicken Lollipop':15,'Beef Nugget':20, 'Americano':180,'Red Velvet':150, 'Prawn Tempura':80,'Saute Veg':200}
f1 = Foodie('Frodo')
print(f1.show_orders())
print('1----------------------')
f1.order('Chicken Lollipop-3','Beef Nugget-6','Americano-1')
print('2----------------------')
print(f1.show_orders())
print('3----------------------')
f1.order('Red Velvet-1')
print('4----------------------')
f1.pay_tips(20)
print('5----------------------')
print(f1.show_orders())
f2 = Foodie('Bilbo')
print('6----------------------')
f2.order('Prawn Tempura-6','Saute Veg-1')
print('7----------------------')
f2.pay_tips()
print('8----------------------')
print(f2.show_orders())
# Out:
# Frodo has 0 item(s) in the cart.
# Items: []
# Total spent: 0.
# 1----------------------
# Ordered - Chicken Lollipop, quantity - 3, price (per Unit) - 15.
# Total price - 45
# Ordered - Beef Nugget, quantity - 6, price (per Unit) - 20.
# Total price - 120
# Ordered - Americano, quantity - 1, price (per Unit) - 180.
# Total price - 180
# 2----------------------
# Frodo has 3 item(s) in the cart.
# Items: ['Chicken Lollipop', 'Beef Nugget', 'Americano']
# Total spent: 345.
# 3----------------------
# Ordered - Red Velvet, quantity - 1, price (per Unit) - 150.
# Total price - 150
# 4----------------------
# Gives 20/- tips to the waiter.
# 5----------------------
# Frodo has 4 item(s) in the cart.
# Items: ['Chicken Lollipop', 'Beef Nugget', 'Americano', 'Red Velvet']
# Total spent: 515.
# 6----------------------
# Ordered - Prawn Tempura, quantity - 6, price (per Unit) - 80.
# Total price - 480
# Ordered - Saute Veg, quantity - 1, price (per Unit) - 200.
# Total price - 200
# 7----------------------
# No tips to the waiter.
# 8----------------------
# Bilbo has 2 item(s) in the cart.
# Items: ['Prawn Tempura', 'Saute Veg']
# Total spent: 680.

# %% [markdown]
# Task 3

# %%
class Department:
  def __init__(self, dept = 'ChE Department', sec = 5):
    self.department = dept
    self.section = sec
    print(f'The {self.department} has {self.section} sections.')

  def add_students(self, *tup): # tup = no. of std. per sec.
    if len(tup) == self.section:
      sum = 0 # sum of all students
      for add in tup:
        sum += add
      self.avg = round(sum/self.section, 2)
      print(f'The {self.department} has an average of {self.avg} students in each section.')
    else:
      self.avg = 0
      print(f"The {self.department} doesn't have {len(tup)} sections.")

  def merge_Department(self, *tup): # tup = given departments
    tstudent = self.avg * self.section
    for dept in tup:
      print(f'{dept.department} is merged to {self.department}.')
      tstudent += dept.avg * dept.section
    self.avg = round(tstudent / self.section, 2)
    return f'Now the {self.department} has an average of {self.avg} students in each section.'



d1 = Department()
print('1-----------------------------')
d2 = Department('MME Department')
print('2-----------------------------')
d3 = Department('NCE Department', 8)
print('3-----------------------------')
d1.add_students(12, 23, 12, 34, 21)
print('4-----------------------------')
d2.add_students(40, 30, 21)
print('5-----------------------------')
d3.add_students(12, 34, 41, 17, 30, 22, 32, 51)
print('6-----------------------------')
mega = Department('Engineering Department', 10)
print('7-----------------------------')
mega.add_students(21,30,40,36,10,32,27,51,45,15)
print('8-----------------------------')
print(mega.merge_Department(d1, d2))
print('9-----------------------------')
print(mega.merge_Department(d3))
# Out:
# The ChE Department has 5 sections.
# 1-----------------------------
# The MME Department has 5 sections.
# 2-----------------------------
# The NCE Department has 8 sections.
# 3-----------------------------
# The ChE Department has an average of 20.4 students in each section.
# 4-----------------------------
# The MME Department doesn't have 3 sections.
# 5-----------------------------
# The NCE Department has an average of 29.88 students in each section.
# 6-----------------------------
# The Engineering Department has 10 sections.
# 7-----------------------------
# The Engineering Department has an average of 30.7 students in each section.
# 8-----------------------------
# ChE Department is merged to Engineering Department.
# MME Department is merged to Engineering Department.
# Now the Engineering Department has an average of 40.9 students in each section.
# 9-----------------------------
# NCE Department is merged to Engineering Department.
# Now the Engineering Department has an average of 64.8 students in each section.

# %% [markdown]
# Task 4

# %%
class Shopidify:
  guest_count = 0
  def __init__(self, name = 'Guest'):
    self.name = name
    self.cart = {}
    self.transaction = 0
    if name == 'Guest':
      Shopidify.guest_count += 1
      print(f'Welcome to Shopidify {Shopidify.guest_count}')
    else:
      print(f'Welcome {name} to Shopidify')

  def add_to_cart(self, items, num = 1):
    if type(items) == list or type(items) == tuple:
      for item in range(0, len(items) - 1, 2):
        if item in self.cart:
          self.cart[items[item]] += items[item + 1]
        else:
          self.cart[items[item]] = items[item + 1]
    else:
      if items in self.cart:
        self.cart[items] += num
      else:
        self.cart[items] = num

  def display_cart(self):
    print(f'Items in the cart for {self.name}:')
    for item, num in self.cart.items():
      print(f'- {item}: {num}x')

  def checkout(self):
    self.transaction += 1
    print('Checkout completed for', self.name)
    self.prevCart = self.cart
    self.cart = {}

  def display_history(self):
    print(f'Purchase history for {self.name}:')
    print(f'Transaction {self.transaction}:')
    for item, num in self.prevCart.items():
      print(f'- {item}: {num}x')


guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
g2 = Shopidify()
# Out:
# Welcome to Shopidify 1
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 3x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for Guest
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest:
# Transaction 1:
# - Air Jordan: 3x
# - Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for John
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John:
# Transaction 1:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome to Shopidify 2

# %%
class Shopidify:
  def __init__(self, name = 'Guest'):
    self.name = name
    self.cart = {}
    self.transaction = 0
    if name == 'Guest':
      print(f'Welcome to Shopidify 1')
    else:
      print(f'Welcome {name} to Shopidify')

  def add_to_cart(self, items, num = 1):
    if type(items) == list or type(items) == tuple:
      for item in range(0, len(items) - 1, 2):
        if item in self.cart:
          self.cart[items[item]] += items[item + 1]
        else:
          self.cart[items[item]] = items[item + 1]
    else:
      if items in self.cart:
        self.cart[items] += num
      else:
        self.cart[items] = num

  def display_cart(self):
    print(f'Items in the cart for {self.name}:')
    for item, num in self.cart.items():
      print(f'- {item}: {num}x')

  def checkout(self):
    self.transaction += 1
    print('Checkout completed for', self.name)
    self.prevCart = self.cart
    self.cart = {}

  def display_history(self):
    print(f'Purchase history for {self.name}:')
    print(f'Transaction {self.transaction}:')
    for item, num in self.prevCart.items():
      print(f'- {item}: {num}x')


guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify 1
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 3x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for Guest
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest:
# Transaction 1:
# - Air Jordan: 3x
# - Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for John
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John:
# Transaction 1:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# Task 5

# %%
class Author:
  def __init__(self, author = None):
    self.name = author
    self.books = {}
    self.bcount = 0 # book counting
  def setName(self, author):
    self.name = author
  def addBook(self, bname, genre): # bname = book name
    if self.name == None:
      print('A book can not be added without author name')
    else:
      self.bcount += 1
      if genre in self.books:
        self.books[genre] = f'{self.books[genre]}, {bname}'
      else:
        self.books[genre] = bname
  def printDetail(self):
    print('Number of Book(s):', self.bcount)
    print('Author Name:', self.name)
    for genre, book in self.books.items():
      print(f'{genre}: {book}')

a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook('Onnobhubon', 'Science Fiction')
a2.addBook('Megher Upor Bari', 'Horror')
print("=================================")
a2.printDetail()
a2.addBook('Ireena', 'Science Fiction')
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# =================================
# A book can not be added without author name
# =================================
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# =================================
# =================================
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# =================================
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon, Ireena
# Horror: Megher Upor Bari
# =================================
